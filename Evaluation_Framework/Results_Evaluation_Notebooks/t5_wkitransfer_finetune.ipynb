# %%
import numpy as np
import pandas as pd
import os
import json

cwd = os.getcwd()

results_path = cwd[:-28] + "Results/Wiki-Finetune/T5_wiki_ft_lr{}_bs{}_epchs{}/all_scores_range_0_10_trail_{}.npz"
results_path_sbert = cwd[:-28] + "Results/Wiki-Finetune/T5_wiki_ft_lr{}_bs{}_epchs{}/all_sbert_scores_0_10_trail_{}.npz"

results_intent_path = cwd[:-28] + "Results/Wiki-Finetune/T5_wiki_ft_lr{}_bs{}_epchs{}/all_scores_range_by_intent_0_10_trail_{}.txt"

intents = ["What is the state's policy regarding education?",
           "What are the major historical events in this state?",
           "How is the weather of the state?",
           "Which places seem interesting to you for visiting in this state?",
           "What are some of the most interesting things about this state?"]

sample_size = 1
learning_rates = [1e-5, 1e-6, 1e-7, 1e-8]
batch_sizes = [8, 12, 16]
total_epochs = [5, 10, 30]

model = "Wiki Finetuned: lr: {}, bs: {}, epochs: {}"

# %%
# sbert_temp = np.load(results_path_sbert.format(1e-5, 8, 5, 0))
# data_sbert = sbert_temp['scores']

# %%
# print(data_sbert.mean(axis=1).mean(axis=0))

# %%
for lr in learning_rates:
    for bs in batch_sizes:
        for epochs in total_epochs:
            total_data = None
            total_data_sbert = []
            total_data_intent = {}

            for intent in intents:
                total_data_intent[intent] = []

            # get all of the "normal" data
            for i in range(sample_size):
                temp = np.load(results_path.format(lr, bs, epochs, i))
                sbert_temp = np.load(results_path_sbert.format(lr, bs, epochs, i))
                data = temp['scores']
                data_sbert = sbert_temp['scores']
                
                if total_data is None:
                    # we need to take the mean of axis-one first because each "user-sample" contains a set of predicted summaries. So we first avg those sets, before average across all the data/trials
                    total_data = data.mean(axis=1)
                    total_data_sbert = data_sbert.mean(axis=1)
                else:
                    total_data = np.concatenate((total_data, data.mean(axis=1)), axis=0)
                    total_data_sbert = np.concatenate((total_data_sbert, data_sbert.mean(axis=1)), axis=0)

            # # get all of the "by-intent" data
            # for i in range(sample_size):
            #     res = None
            #     with open(results_intent_path.format(lr, bs, epochs, i)) as f:
            #         res = json.load(f)

            #     for intent in intents:
            #         total_data_intent[intent].extend(np.mean(res[intent], axis=1).tolist())

            # now calculate the relavent stats
            total_mean = np.mean(total_data, axis=0)
            total_stddev = np.std(total_data, axis=0)

            total_mean_sbert = np.mean(total_data_sbert, axis=0)
            total_stddev_sbert = np.std(total_data_sbert, axis=0)

            mean_intent = {}
            stddev_intent = {}

            # for intent in intents:
            #     mean = np.mean(total_data_intent[intent], axis=0)
            #     stddev = np.std(total_data_intent[intent], axis=0)
            #     mean_intent[intent] = mean
            #     stddev_intent[intent] = stddev

            metrics = ["Rouge-1", "Rouge-2", "Rouge-L"]

            for i, (row_m, row_s) in enumerate(zip(total_mean, total_stddev)):
                row_str = model.format(lr, bs, epochs) + " & "
                for col_m, col_s in zip(row_m, row_s):
                    row_str += str(np.round(col_m, 4)) + " $\\pm$ " + str(np.round(col_s, 4)) + " & "
                
                row_str = row_str[:-3]
                row_str += " \\\\"
                print(metrics[i])
                print(row_str)
            print(model.format(lr, bs, epochs) + " & " + str(np.round(total_mean_sbert, 4)) + " $\\pm$ " + str(np.round(total_stddev_sbert, 4)) + " \\\\")

            print("\n\n\n")
# Out:
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 5 & 0.0803 $\pm$ 0.0202 & 0.3997 $\pm$ 0.1208 & 0.13 $\pm$ 0.0307 & 0.0812 $\pm$ 0.0192 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 5 & 0.0191 $\pm$ 0.0082 & 0.1043 $\pm$ 0.0659 & 0.0312 $\pm$ 0.014 & 0.0195 $\pm$ 0.0087 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 5 & 0.0586 $\pm$ 0.0128 & 0.3014 $\pm$ 0.1036 & 0.0953 $\pm$ 0.0206 & 0.0596 $\pm$ 0.0129 \\
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 5 & 0.3631 $\pm$ 0.0965 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 10 & 0.0278 $\pm$ 0.0126 & 0.0898 $\pm$ 0.0778 & 0.039 $\pm$ 0.0174 & 0.0244 $\pm$ 0.0109 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 10 & 0.007 $\pm$ 0.0047 & 0.0301 $\pm$ 0.0419 & 0.0098 $\pm$ 0.0061 & 0.0061 $\pm$ 0.0038 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 10 & 0.0237 $\pm$ 0.0104 & 0.0756 $\pm$ 0.0626 & 0.0332 $\pm$ 0.0142 & 0.0207 $\pm$ 0.0089 \\
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 10 & 0.2025 $\pm$ 0.1396 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 30 & 0.0401 $\pm$ 0.042 & 0.0293 $\pm$ 0.0319 & 0.0333 $\pm$ 0.0356 & 0.0208 $\pm$ 0.0222 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 30 & 0.0001 $\pm$ 0.0002 & 0.0001 $\pm$ 0.0002 & 0.0001 $\pm$ 0.0002 & 0.0 $\pm$ 0.0001 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 30 & 0.0388 $\pm$ 0.0404 & 0.0281 $\pm$ 0.03 & 0.032 $\pm$ 0.0337 & 0.02 $\pm$ 0.0211 \\
# Wiki Finetuned: lr: 1e-05, bs: 8, epochs: 30 & -0.0469 $\pm$ 0.0298 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 5 & 0.0977 $\pm$ 0.0186 & 0.5437 $\pm$ 0.078 & 0.1627 $\pm$ 0.027 & 0.1017 $\pm$ 0.0169 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 5 & 0.0241 $\pm$ 0.0083 & 0.1492 $\pm$ 0.0695 & 0.0408 $\pm$ 0.0142 & 0.0255 $\pm$ 0.0089 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 5 & 0.0727 $\pm$ 0.0139 & 0.4103 $\pm$ 0.0763 & 0.1213 $\pm$ 0.0206 & 0.0758 $\pm$ 0.0129 \\
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 5 & 0.4336 $\pm$ 0.0898 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 10 & 0.0556 $\pm$ 0.0226 & 0.2634 $\pm$ 0.1669 & 0.0878 $\pm$ 0.0376 & 0.0549 $\pm$ 0.0235 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 10 & 0.0132 $\pm$ 0.0083 & 0.0679 $\pm$ 0.0668 & 0.0211 $\pm$ 0.0144 & 0.0132 $\pm$ 0.009 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 10 & 0.0435 $\pm$ 0.0155 & 0.2072 $\pm$ 0.1255 & 0.0687 $\pm$ 0.0262 & 0.0429 $\pm$ 0.0164 \\
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 10 & 0.2897 $\pm$ 0.0966 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 30 & 0.0413 $\pm$ 0.0417 & 0.0919 $\pm$ 0.129 & 0.0501 $\pm$ 0.0558 & 0.0313 $\pm$ 0.0349 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 30 & 0.0004 $\pm$ 0.001 & 0.0012 $\pm$ 0.0028 & 0.0006 $\pm$ 0.0015 & 0.0004 $\pm$ 0.0009 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 30 & 0.0409 $\pm$ 0.0414 & 0.0907 $\pm$ 0.1277 & 0.0494 $\pm$ 0.0551 & 0.0309 $\pm$ 0.0345 \\
# Wiki Finetuned: lr: 1e-05, bs: 12, epochs: 30 & -0.0407 $\pm$ 0.0465 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 5 & 0.101 $\pm$ 0.0163 & 0.5286 $\pm$ 0.0714 & 0.1659 $\pm$ 0.0218 & 0.1037 $\pm$ 0.0136 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 5 & 0.0233 $\pm$ 0.0053 & 0.1352 $\pm$ 0.0458 & 0.0388 $\pm$ 0.0084 & 0.0243 $\pm$ 0.0052 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 5 & 0.0716 $\pm$ 0.01 & 0.3871 $\pm$ 0.0593 & 0.1183 $\pm$ 0.0132 & 0.0739 $\pm$ 0.0082 \\
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 5 & 0.4499 $\pm$ 0.062 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 10 & 0.0761 $\pm$ 0.0257 & 0.3701 $\pm$ 0.1583 & 0.122 $\pm$ 0.0414 & 0.0763 $\pm$ 0.0259 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 10 & 0.0193 $\pm$ 0.0109 & 0.1035 $\pm$ 0.0805 & 0.0314 $\pm$ 0.0189 & 0.0196 $\pm$ 0.0118 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 10 & 0.0579 $\pm$ 0.0191 & 0.2914 $\pm$ 0.1422 & 0.0935 $\pm$ 0.0326 & 0.0584 $\pm$ 0.0204 \\
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 10 & 0.3485 $\pm$ 0.1064 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 30 & 0.0222 $\pm$ 0.0239 & 0.0601 $\pm$ 0.0649 & 0.031 $\pm$ 0.0323 & 0.0194 $\pm$ 0.0202 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 30 & 0.001 $\pm$ 0.0014 & 0.0028 $\pm$ 0.0045 & 0.0014 $\pm$ 0.0021 & 0.0009 $\pm$ 0.0013 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 30 & 0.0221 $\pm$ 0.0238 & 0.0595 $\pm$ 0.064 & 0.0308 $\pm$ 0.032 & 0.0192 $\pm$ 0.02 \\
# Wiki Finetuned: lr: 1e-05, bs: 16, epochs: 30 & 0.0205 $\pm$ 0.0876 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 5 & 0.107 $\pm$ 0.0181 & 0.5113 $\pm$ 0.0839 & 0.1722 $\pm$ 0.0222 & 0.1077 $\pm$ 0.0139 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 5 & 0.0247 $\pm$ 0.0084 & 0.135 $\pm$ 0.0724 & 0.0407 $\pm$ 0.0143 & 0.0254 $\pm$ 0.0089 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 5 & 0.0736 $\pm$ 0.0091 & 0.365 $\pm$ 0.0801 & 0.1192 $\pm$ 0.0094 & 0.0745 $\pm$ 0.0059 \\
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 5 & 0.4396 $\pm$ 0.0711 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 10 & 0.1065 $\pm$ 0.0147 & 0.5162 $\pm$ 0.0769 & 0.1722 $\pm$ 0.019 & 0.1076 $\pm$ 0.0119 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 10 & 0.0246 $\pm$ 0.0078 & 0.1339 $\pm$ 0.065 & 0.0405 $\pm$ 0.0133 & 0.0253 $\pm$ 0.0083 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 10 & 0.0742 $\pm$ 0.0087 & 0.3685 $\pm$ 0.068 & 0.1205 $\pm$ 0.0107 & 0.0753 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 10 & 0.4328 $\pm$ 0.0642 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 30 & 0.0988 $\pm$ 0.0185 & 0.5309 $\pm$ 0.0711 & 0.1634 $\pm$ 0.0262 & 0.1021 $\pm$ 0.0163 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 30 & 0.0233 $\pm$ 0.0077 & 0.1418 $\pm$ 0.0649 & 0.0392 $\pm$ 0.0129 & 0.0245 $\pm$ 0.008 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 30 & 0.0723 $\pm$ 0.011 & 0.3956 $\pm$ 0.0663 & 0.1199 $\pm$ 0.0154 & 0.0749 $\pm$ 0.0096 \\
# Wiki Finetuned: lr: 1e-06, bs: 8, epochs: 30 & 0.4537 $\pm$ 0.0803 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 5 & 0.1072 $\pm$ 0.0199 & 0.5105 $\pm$ 0.0688 & 0.1731 $\pm$ 0.0228 & 0.1082 $\pm$ 0.0143 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 5 & 0.0246 $\pm$ 0.0078 & 0.1286 $\pm$ 0.0547 & 0.0404 $\pm$ 0.0127 & 0.0253 $\pm$ 0.0079 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 5 & 0.0745 $\pm$ 0.0103 & 0.3648 $\pm$ 0.0675 & 0.121 $\pm$ 0.0108 & 0.0756 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 5 & 0.4269 $\pm$ 0.0644 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 10 & 0.0997 $\pm$ 0.0177 & 0.5057 $\pm$ 0.0799 & 0.1623 $\pm$ 0.0209 & 0.1014 $\pm$ 0.0131 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 10 & 0.0237 $\pm$ 0.0081 & 0.1354 $\pm$ 0.0726 & 0.0393 $\pm$ 0.0138 & 0.0246 $\pm$ 0.0086 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 10 & 0.0701 $\pm$ 0.0093 & 0.3654 $\pm$ 0.0777 & 0.1146 $\pm$ 0.0094 & 0.0716 $\pm$ 0.0059 \\
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 10 & 0.4327 $\pm$ 0.0707 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 30 & 0.1016 $\pm$ 0.0227 & 0.519 $\pm$ 0.0769 & 0.1637 $\pm$ 0.0282 & 0.1023 $\pm$ 0.0177 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 30 & 0.0219 $\pm$ 0.0073 & 0.1313 $\pm$ 0.0624 & 0.0366 $\pm$ 0.0126 & 0.0229 $\pm$ 0.0079 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 30 & 0.0724 $\pm$ 0.0166 & 0.3757 $\pm$ 0.0627 & 0.1164 $\pm$ 0.0169 & 0.0728 $\pm$ 0.0106 \\
# Wiki Finetuned: lr: 1e-06, bs: 12, epochs: 30 & 0.4323 $\pm$ 0.073 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 5 & 0.1072 $\pm$ 0.018 & 0.5083 $\pm$ 0.0677 & 0.1732 $\pm$ 0.0205 & 0.1083 $\pm$ 0.0128 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 5 & 0.0244 $\pm$ 0.0071 & 0.1264 $\pm$ 0.0509 & 0.04 $\pm$ 0.0115 & 0.025 $\pm$ 0.0072 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 5 & 0.0753 $\pm$ 0.0098 & 0.3659 $\pm$ 0.0634 & 0.1223 $\pm$ 0.0098 & 0.0764 $\pm$ 0.0061 \\
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 5 & 0.4364 $\pm$ 0.0598 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 10 & 0.1047 $\pm$ 0.019 & 0.5156 $\pm$ 0.0824 & 0.1694 $\pm$ 0.0237 & 0.1059 $\pm$ 0.0148 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 10 & 0.0249 $\pm$ 0.0081 & 0.1404 $\pm$ 0.0782 & 0.0411 $\pm$ 0.0138 & 0.0257 $\pm$ 0.0086 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 10 & 0.0723 $\pm$ 0.0093 & 0.3706 $\pm$ 0.0824 & 0.1178 $\pm$ 0.0096 & 0.0736 $\pm$ 0.006 \\
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 10 & 0.4333 $\pm$ 0.071 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 30 & 0.1015 $\pm$ 0.021 & 0.517 $\pm$ 0.0718 & 0.1651 $\pm$ 0.0265 & 0.1032 $\pm$ 0.0166 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 30 & 0.0224 $\pm$ 0.0065 & 0.1292 $\pm$ 0.0572 & 0.0372 $\pm$ 0.0112 & 0.0232 $\pm$ 0.007 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 30 & 0.0706 $\pm$ 0.0119 & 0.3692 $\pm$ 0.0602 & 0.1152 $\pm$ 0.0136 & 0.072 $\pm$ 0.0085 \\
# Wiki Finetuned: lr: 1e-06, bs: 16, epochs: 30 & 0.4339 $\pm$ 0.0628 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 5 & 0.1091 $\pm$ 0.0166 & 0.5094 $\pm$ 0.0725 & 0.1758 $\pm$ 0.0197 & 0.1098 $\pm$ 0.0123 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 5 & 0.0239 $\pm$ 0.0055 & 0.123 $\pm$ 0.0452 & 0.0392 $\pm$ 0.0092 & 0.0245 $\pm$ 0.0057 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 5 & 0.0759 $\pm$ 0.0097 & 0.3615 $\pm$ 0.0615 & 0.1228 $\pm$ 0.0116 & 0.0767 $\pm$ 0.0073 \\
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 5 & 0.4303 $\pm$ 0.0629 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 10 & 0.108 $\pm$ 0.0174 & 0.5128 $\pm$ 0.0693 & 0.1743 $\pm$ 0.0204 & 0.109 $\pm$ 0.0128 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 10 & 0.024 $\pm$ 0.0053 & 0.1263 $\pm$ 0.0438 & 0.0394 $\pm$ 0.0085 & 0.0246 $\pm$ 0.0053 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 10 & 0.0752 $\pm$ 0.0096 & 0.366 $\pm$ 0.065 & 0.1219 $\pm$ 0.0109 & 0.0762 $\pm$ 0.0068 \\
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 10 & 0.4428 $\pm$ 0.0598 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 30 & 0.1067 $\pm$ 0.0178 & 0.5077 $\pm$ 0.0681 & 0.1724 $\pm$ 0.0205 & 0.1078 $\pm$ 0.0128 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 30 & 0.024 $\pm$ 0.0077 & 0.1249 $\pm$ 0.0529 & 0.0394 $\pm$ 0.0126 & 0.0246 $\pm$ 0.0079 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 30 & 0.0751 $\pm$ 0.0096 & 0.366 $\pm$ 0.0637 & 0.1219 $\pm$ 0.01 & 0.0762 $\pm$ 0.0063 \\
# Wiki Finetuned: lr: 1e-07, bs: 8, epochs: 30 & 0.4351 $\pm$ 0.0614 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 5 & 0.1104 $\pm$ 0.0158 & 0.5053 $\pm$ 0.0775 & 0.177 $\pm$ 0.0185 & 0.1107 $\pm$ 0.0116 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 5 & 0.0237 $\pm$ 0.0057 & 0.1205 $\pm$ 0.0476 & 0.0388 $\pm$ 0.0097 & 0.0242 $\pm$ 0.0061 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 5 & 0.0765 $\pm$ 0.0092 & 0.3576 $\pm$ 0.0656 & 0.1232 $\pm$ 0.0112 & 0.077 $\pm$ 0.007 \\
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 5 & 0.4267 $\pm$ 0.0651 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 10 & 0.1104 $\pm$ 0.0158 & 0.5053 $\pm$ 0.0775 & 0.177 $\pm$ 0.0185 & 0.1107 $\pm$ 0.0116 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 10 & 0.0238 $\pm$ 0.0058 & 0.121 $\pm$ 0.049 & 0.0389 $\pm$ 0.0098 & 0.0243 $\pm$ 0.0062 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 10 & 0.0765 $\pm$ 0.0092 & 0.3576 $\pm$ 0.0656 & 0.1232 $\pm$ 0.0112 & 0.077 $\pm$ 0.007 \\
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 10 & 0.4269 $\pm$ 0.0658 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 30 & 0.1084 $\pm$ 0.018 & 0.509 $\pm$ 0.0686 & 0.1747 $\pm$ 0.021 & 0.1092 $\pm$ 0.0131 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 30 & 0.0243 $\pm$ 0.0077 & 0.1244 $\pm$ 0.053 & 0.0397 $\pm$ 0.0127 & 0.0248 $\pm$ 0.0079 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 30 & 0.0753 $\pm$ 0.0099 & 0.3641 $\pm$ 0.0619 & 0.122 $\pm$ 0.0106 & 0.0763 $\pm$ 0.0066 \\
# Wiki Finetuned: lr: 1e-07, bs: 12, epochs: 30 & 0.435 $\pm$ 0.0612 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 5 & 0.1093 $\pm$ 0.0165 & 0.5168 $\pm$ 0.0685 & 0.1764 $\pm$ 0.019 & 0.1103 $\pm$ 0.0119 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 5 & 0.0246 $\pm$ 0.0051 & 0.1281 $\pm$ 0.0438 & 0.0405 $\pm$ 0.0086 & 0.0253 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 5 & 0.0762 $\pm$ 0.0094 & 0.3681 $\pm$ 0.0596 & 0.1236 $\pm$ 0.0109 & 0.0772 $\pm$ 0.0068 \\
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 5 & 0.4398 $\pm$ 0.0659 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 10 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 10 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 10 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 10 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 30 & 0.1082 $\pm$ 0.0178 & 0.5084 $\pm$ 0.0693 & 0.1744 $\pm$ 0.0207 & 0.109 $\pm$ 0.0129 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 30 & 0.0243 $\pm$ 0.0077 & 0.1244 $\pm$ 0.0531 & 0.0397 $\pm$ 0.0127 & 0.0248 $\pm$ 0.0079 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 30 & 0.0751 $\pm$ 0.0096 & 0.3635 $\pm$ 0.0624 & 0.1217 $\pm$ 0.0102 & 0.0761 $\pm$ 0.0063 \\
# Wiki Finetuned: lr: 1e-07, bs: 16, epochs: 30 & 0.4349 $\pm$ 0.0612 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 5 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 5 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 5 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 5 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 10 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 10 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 10 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 10 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 30 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 30 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 30 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 8, epochs: 30 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 5 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 5 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 5 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 5 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 10 & 0.1098 $\pm$ 0.0161 & 0.5088 $\pm$ 0.0731 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 10 & 0.0241 $\pm$ 0.0053 & 0.1229 $\pm$ 0.0453 & 0.0394 $\pm$ 0.009 & 0.0246 $\pm$ 0.0056 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 10 & 0.0768 $\pm$ 0.0092 & 0.3629 $\pm$ 0.0606 & 0.1241 $\pm$ 0.0108 & 0.0776 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 10 & 0.4319 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 30 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 30 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 30 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 12, epochs: 30 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 5 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 5 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 5 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 5 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 10 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 10 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 10 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 10 & 0.4333 $\pm$ 0.0625 \\
#
#
#
#
# Rouge-1
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 30 & 0.1098 $\pm$ 0.0161 & 0.5109 $\pm$ 0.0712 & 0.1767 $\pm$ 0.0188 & 0.1104 $\pm$ 0.0117 \\
# Rouge-2
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 30 & 0.0244 $\pm$ 0.0052 & 0.125 $\pm$ 0.044 & 0.0399 $\pm$ 0.0087 & 0.0249 $\pm$ 0.0054 \\
# Rouge-L
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 30 & 0.0767 $\pm$ 0.0092 & 0.3645 $\pm$ 0.0599 & 0.1241 $\pm$ 0.0108 & 0.0775 $\pm$ 0.0067 \\
# Wiki Finetuned: lr: 1e-08, bs: 16, epochs: 30 & 0.4333 $\pm$ 0.0625 \\
