# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
intents = ["What drives the economy in this state?",
           "What are the available modes of transport in this state?",
           "How is the government structured in this state?",
           "What about this state's arts and culture attracts you the most?",
           "The main reasons why you would like living in this state"]

intent_labels = ["I2", "I4", "I5", "I7", "I10"]


f1 = [0.1833, 0.1658, 0.1347, 0.1347, 0.1445, 0.1366, 0.1456, 0.1423]
f1_std = [0.0403, 0.0229, 0.0279, 0.0279, 0.0271, 0.028, 0.0268, 0.0257]

sbert = [0.5388, 0.4661, 0.4472, 0.4471, 0.4806, 0.4612, 0.4841, 0.484]
sbert_std = [0.0782, 0.0719, 0.0784, 0.0784, 0.0762, 0.0721, 0.0753, 0.0726]


f1_intent_lead = [0.1142, 0.1039, 0.1119, 0.1143, 0.1295]
f1_intent_std_lead = [0.0225, 0.009, 0.0081, 0.0279, 0.0383]

sbert_intent_lead = [0.5513, 0.5315, 0.5041, 0.4985, 0.6039]
sbert_intent_std_lead = [0.057, 0.0464, 0.0483, 0.093, 0.0895]


f1_intent_rand = [0.1023, 0.0973, 0.108, 0.1047, 0.1068]
f1_intent_std_rand = [0.0137, 0.0125, 0.0134, 0.014, 0.0152]

sbert_intent_rand = [0.4777, 0.4522, 0.4268, 0.4608, 0.513]
sbert_intent_std_rand = [0.061, 0.0597, 0.0598, 0.0782, 0.0717]


f1_intent_t5 = [0.085, 0.082, 0.0854, 0.0806, 0.0876]
f1_intent_std_t5 = [0.018, 0.0145, 0.0176, 0.016, 0.0199]

sbert_intent_t5 = [0.4747, 0.4276, 0.4237, 0.406, 0.4994]
sbert_intent_std_t5 = [0.0549, 0.059, 0.0608, 0.0913, 0.0834]


f1_intent_t5b = [0.085, 0.0821, 0.0854, 0.0806, 0.0875]
f1_intent_std_t5b = [0.018, 0.0146, 0.0176, 0.016, 0.0199]

sbert_intent_t5b = [0.4746, 0.4276, 0.4237, 0.406, 0.4994]
sbert_intent_std_t5b = [0.0549, 0.0588, 0.0608, 0.0913, 0.0833]


f1_intent_t5a = [0.0924, 0.087, 0.091, 0.0861, 0.0949]
f1_intent_std_t5a = [0.0162, 0.0143, 0.0161, 0.0156, 0.0204]

sbert_intent_t5a = [0.5142, 0.4521, 0.4548, 0.436, 0.5417]
sbert_intent_std_t5a = [0.0515, 0.0533, 0.0553, 0.0811, 0.0792] 

f1_intent_t5w = [0.0854, 0.0835, 0.0861, 0.0819, 0.0898]
f1_intent_std_t5w = [0.0183, 0.0141, 0.0173, 0.0158, 0.0204]

sbert_intent_t5w = [0.4839, 0.4413, 0.4363, 0.4184, 0.5218]
sbert_intent_std_t5w = [0.0542, 0.0433, 0.0554, 0.0763, 0.0772]

f1_intent_t5wb = [0.0921, 0.0882, 0.0925, 0.0874, 0.0945]
f1_intent_std_t5wb = [0.0164, 0.0139, 0.0185, 0.0153, 0.0182]

sbert_intent_t5wb = [0.5108, 0.4473, 0.4676, 0.4443, 0.5482]
sbert_intent_std_t5wb = [0.0517, 0.0434, 0.0575, 0.084, 0.0787]

f1_intent_t5wa = [0.0892, 0.0866, 0.0908, 0.0865, 0.0915]
f1_intent_std_t5wa = [0.0141, 0.0153, 0.0168, 0.0146, 0.0184]

sbert_intent_t5wa = [0.5179, 0.4496, 0.4633, 0.4436, 0.5422]
sbert_intent_std_t5wa = [0.0519, 0.0505, 0.0515, 0.0758, 0.0739]


x_pos = np.arange(len(f1))
x_pos_intent = np.arange(len(intent_labels))
models = ["LeadN", "RandomN", "T5", "T5-B", "T5-A", "T5-W", "T5-WB", "T5-WB"]

output_path = "final_results_overall/"

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, sbert, yerr=sbert_std, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('SBERT Cosine-Sim.')
ax.set_xticks(x_pos)
ax.set_xticklabels(models, rotation=45)
ax.set_title('SBERT Embedding Cosine-Similarity (stddev) vs. Model')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig(output_path + "sbert_all.png")
plt.show()

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, f1, yerr=f1_std, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Rouge1 F1-Score')
ax.set_xticks(x_pos)
ax.set_xticklabels(models, rotation=45)
ax.set_title('Rouge1 F1 Score (stddev) vs. Model')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig(output_path + "rl_f1_all.png")
plt.show()

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, sbert, yerr=sbert_std, align='center', color='red', alpha=0.5, ecolor='black', capsize=10, label="SBERT")
ax.bar(x_pos, f1, yerr=f1_std, align='center', color='blue', alpha=0.75, ecolor='black', capsize=10, label="F1")
ax.set_ylabel('Score', size=13)
ax.set_xticks(x_pos)
ax.set_xticklabels(models, rotation=45, fontsize=13)
ax.set_title('SBERT and RougeL F1 Score (stddev) vs. Model', size=15)
ax.set_ylim(0, 0.75)
ax.yaxis.grid(True)
ax.legend()

# Save the figure and show
plt.tight_layout()
plt.savefig(output_path + "sbert_rl_f1_all.png")
plt.show()

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos[2:], sbert[2:], yerr=sbert_std[2:], align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('SBERT Cosine-Sim.')
ax.set_xticks(x_pos[2:])
ax.set_xticklabels(models[2:], rotation=45)
ax.set_title('SBERT Embedding Cosine-Similarity (stddev) vs. Model')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig(output_path + "sbert_no_baselines.png")
plt.show()

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos[2:], f1[2:], yerr=f1_std[2:], align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Rouge F1-Score')
ax.set_xticks(x_pos[2:])
ax.set_xticklabels(models[2:], rotation=45)
ax.set_title('Rouge1 F1-Scores (stddev) vs. Model')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig(output_path + "r1_f1_no_baselines.png")
plt.show()

# %%
N = 8
ind = x_pos_intent  # the x locations for the groups
width = 0.1      # the width of the bars

fig, ax = plt.subplots(1, 1, )

rects1 = ax.bar(ind, f1_intent_lead, width, yerr=f1_intent_std_lead, ecolor='black', capsize=1, label="LeadN")
rects2 = ax.bar(ind+width, f1_intent_rand, width, yerr=f1_intent_std_rand, ecolor='black', capsize=1, label="RandN")
rects3 = ax.bar(ind+width*2, f1_intent_t5, width, yerr=f1_intent_std_t5, ecolor='black', capsize=1, label="T5")
rects4 = ax.bar(ind+width*3, f1_intent_t5b, width, yerr=f1_intent_std_t5b, ecolor='black', capsize=1, label="T5-B")
rects5 = ax.bar(ind+width*4, f1_intent_t5a, width, yerr=f1_intent_std_t5a, ecolor='black', capsize=1, label="T5-A")
rects6 = ax.bar(ind+width*5, f1_intent_t5w, width, yerr=f1_intent_std_t5w, ecolor='black', capsize=1, label="T5-W")
rects7 = ax.bar(ind+width*6, f1_intent_t5wb, width, yerr=f1_intent_std_t5wb, ecolor='black', capsize=1, label="T5-WB")
rects8 = ax.bar(ind+width*7, f1_intent_t5wa, width, yerr=f1_intent_std_t5wb, ecolor='black', capsize=1, label="T5-WA")

ax.set_ylabel('Rouge-L F1 Scores', size=14)
ax.set_xticks(ind+4*width-(width/2))
ax.set_xticklabels(intent_labels)
ax.set_xlabel("Intent", size=14)
ax.set_title("Rouge-L F1 vs. Intent", size="16")
ax.legend(bbox_to_anchor=(1., 1.))

plt.tight_layout()
plt.savefig(output_path + "rL_intent.png")
plt.show()

# %%
N = 8
ind = x_pos_intent  # the x locations for the groups
width = 0.1      # the width of the bars

fig, ax = plt.subplots(1, 1, )

ax.bar(ind, sbert_intent_lead, width, yerr=sbert_intent_std_lead, ecolor='black', capsize=1, label="LeadN")
ax.bar(ind+width, sbert_intent_rand, width, yerr=sbert_intent_std_rand, ecolor='black', capsize=1, label="RandN")
ax.bar(ind+width*2, sbert_intent_t5, width, yerr=sbert_intent_std_t5, ecolor='black', capsize=1, label="T5")
ax.bar(ind+width*3, sbert_intent_t5b, width, yerr=sbert_intent_std_t5a, ecolor='black', capsize=1, label="T5-B")
ax.bar(ind+width*4, sbert_intent_t5a, width, yerr=sbert_intent_std_t5b, ecolor='black', capsize=1, label="T5-A")
ax.bar(ind+width*5, sbert_intent_t5w, width, yerr=sbert_intent_std_t5w, ecolor='black', capsize=1, label="T5-W")
ax.bar(ind+width*6, sbert_intent_t5wa, width, yerr=sbert_intent_std_t5wb, ecolor='black', capsize=1, label="T5-WB")
ax.bar(ind+width*7, sbert_intent_t5wb, width, yerr=sbert_intent_std_t5wa, ecolor='black', capsize=1, label="T5-WA")

ax.set_ylabel('SBERT Cos Sim.', size=14)
ax.set_xticks(ind+4*width-(width/2))
ax.set_xticklabels(intent_labels)
ax.set_xlabel("Intent", size=14)
ax.set_title("SBERT Cos-Similarity vs. Intent", size="16")
ax.legend(bbox_to_anchor=(1., 1.))

plt.tight_layout()
plt.savefig(output_path + "sbert_intent.png")
plt.show()

# %%
ind = x_pos_intent  # the x locations for the groups
width = 0.1      # the width of the bars

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[1].bar(ind, sbert_intent_lead, width, yerr=sbert_intent_std_lead, ecolor='black', capsize=1, label="LeadN")
ax[1].bar(ind+width, sbert_intent_rand, width, yerr=sbert_intent_std_rand, ecolor='black', capsize=1, label="RandN")
ax[1].bar(ind+width*2, sbert_intent_t5, width, yerr=sbert_intent_std_t5, ecolor='black', capsize=1, label="T5")
ax[1].bar(ind+width*3, sbert_intent_t5b, width, yerr=sbert_intent_std_t5a, ecolor='black', capsize=1, label="T5-B")
ax[1].bar(ind+width*4, sbert_intent_t5a, width, yerr=sbert_intent_std_t5b, ecolor='black', capsize=1, label="T5-A")
ax[1].bar(ind+width*5, sbert_intent_t5w, width, yerr=sbert_intent_std_t5w, ecolor='black', capsize=1, label="T5-W")
ax[1].bar(ind+width*6, sbert_intent_t5wa, width, yerr=sbert_intent_std_t5wb, ecolor='black', capsize=1, label="T5-WB")
ax[1].bar(ind+width*7, sbert_intent_t5wb, width, yerr=sbert_intent_std_t5wa, ecolor='black', capsize=1, label="T5-WA")

ax[1].set_ylabel('SBERT Cos Sim.', size=14)
ax[1].set_xticks(ind+4*width-(width/2))
ax[1].set_xticklabels(intent_labels)
ax[1].set_xlabel("Intent", size=14)
ax[1].set_title("SBERT Cos-Similarity vs. Intent", size="16")
ax[1].legend(bbox_to_anchor=(1., 1.))


ax[0].bar(ind, f1_intent_lead, width, yerr=f1_intent_std_lead, ecolor='black', capsize=1, label="LeadN")
ax[0].bar(ind+width, f1_intent_rand, width, yerr=f1_intent_std_rand, ecolor='black', capsize=1, label="RandN")
ax[0].bar(ind+width*2, f1_intent_t5, width, yerr=f1_intent_std_t5, ecolor='black', capsize=1, label="T5")
ax[0].bar(ind+width*3, f1_intent_t5b, width, yerr=f1_intent_std_t5b, ecolor='black', capsize=1, label="T5-B")
ax[0].bar(ind+width*4, f1_intent_t5a, width, yerr=f1_intent_std_t5a, ecolor='black', capsize=1, label="T5-A")
ax[0].bar(ind+width*5, f1_intent_t5w, width, yerr=f1_intent_std_t5w, ecolor='black', capsize=1, label="T5-W")
ax[0].bar(ind+width*6, f1_intent_t5wb, width, yerr=f1_intent_std_t5wb, ecolor='black', capsize=1, label="T5-WB")
ax[0].bar(ind+width*7, f1_intent_t5wa, width, yerr=f1_intent_std_t5wb, ecolor='black', capsize=1, label="T5-WA")

ax[0].set_ylabel('Rouge-L F1 Scores', size=14)
ax[0].set_xticks(ind+4*width-(width/2))
ax[0].set_xticklabels(intent_labels)
ax[0].set_xlabel("Intent", size=14)
ax[0].set_title("Rouge-L F1 vs. Intent", size="16")

plt.suptitle("Results by Intent", size=18)
plt.tight_layout()
plt.savefig(output_path + "results_by_intent.png")
plt.show()
