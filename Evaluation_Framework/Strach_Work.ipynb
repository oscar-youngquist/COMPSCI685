# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../SubSumE_Data/processed_state_sentences.csv")

# %%
# !sudo apt-get install git-lfs
# !git lfs install

# %%
# !git clone https://huggingface.co/facebook/bart-base

# %%
from utils.UserDataReader import UserDataReader
import os
from os import listdir

from pathlib import Path

# %%
data_path = "~/Documents/CS685/COMPSCI685/SubSumE_Data/processed_state_sentences.csv"
users_path = "../SubSumE_Data/Test/"
udr = UserDataReader(users_path, data_path, 0, 137)
# Out:
# userInput_99.txt
# userInput_89.txt
# userInput_130.txt
# userInput_92.txt
# userInput_44.txt
# userInput_62.txt
# userInput_55.txt
# userInput_72.txt
# userInput_74.txt
# userInput_2.txt
# userInput_116.txt
# userInput_100.txt
# userInput_63.txt
# userInput_80.txt
# userInput_43.txt
# userInput_52.txt
# userInput_34.txt
# userInput_102.txt
# userInput_22.txt
# userInput_19.txt
# userInput_91.txt
# userInput_127.txt
# userInput_69.txt
# userInput_75.txt
# userInput_122.txt
# userInput_98.txt
# userInput_35.txt
# userInput_70.txt
# userInput_103.txt
# userInput_126.txt
# userInput_128.txt
# userInput_42.txt
# userInput_101.txt
# userInput_131.txt
# userInput_108.txt
# userInput_29.txt
# userInput_56.txt
# userInput_120.txt
# userInput_37.txt
# userInput_66.txt
# userInput_107.txt
# userInput_32.txt
# userInput_9.txt
# userInput_125.txt
# userInput_41.txt
# userInput_1.txt
# userInput_38.txt
# userInput_133.txt
# userInput_47.txt
# userInput_121.txt
# userInput_24.txt
# ...

# %%
users_path = "../SubSumE_Data/Test/"

for i, path in enumerate(listdir(users_path)):
    print("files: %s, example number: %d" %(path, i))
# Out:
# files: userInput_99.txt, example number: 0
# files: userInput_89.txt, example number: 1
# files: userInput_130.txt, example number: 2
# files: userInput_92.txt, example number: 3
# files: userInput_44.txt, example number: 4
# files: userInput_62.txt, example number: 5
# files: userInput_55.txt, example number: 6
# files: userInput_72.txt, example number: 7
# files: userInput_74.txt, example number: 8
# files: userInput_2.txt, example number: 9
# files: userInput_116.txt, example number: 10
# files: userInput_100.txt, example number: 11
# files: userInput_63.txt, example number: 12
# files: userInput_80.txt, example number: 13
# files: userInput_43.txt, example number: 14
# files: userInput_52.txt, example number: 15
# files: userInput_34.txt, example number: 16
# files: userInput_102.txt, example number: 17
# files: userInput_22.txt, example number: 18
# files: userInput_19.txt, example number: 19
# files: userInput_91.txt, example number: 20
# ...
